# %% [markdown]
# # Sprint セグメンテーション2

# %% [markdown]
# ## 1.このSprintについて
#
# ### Sprintの目的
# - セグメンテーションの精度を向上させる
#
# ### どのように学ぶか
# Kaggleコンペティションの情報を参考にセグメンテーションの精度を向上させます。

# %% [markdown]
# ## 2.セグメンテーションの精度向上
#
# 前回に引き続きTGS Salt Identification Challengのデータセットの学習・推定を行います。
#
# [TGS Salt Identification Challenge | Kaggle](https://www.kaggle.com/c/tgs-salt-identification-challenge)

# %% [markdown]
# ### 【問題1】コードレビュー
#
# 転移学習を使用してセグメンテーションの精度を改善したコードを提示するので、レビューを行ってください。
#
# **《視点例》**
#
# - 前回使用した実装とはどのように違うのか
# - 転移学習をどのように行っているか

# %% [markdown]
# - [学習済のresnet50を利用して、unetを実装したファイル](https://github.com/satoshi30/diveintocode-ml/blob/master/Term2_DeepLearning/Sprint20/03_models_pretrained_and_more(resnet_unet).ipynb)
# - resnet50をencoderとし、encoderの中間出力（各層でpoolingされる前の層）をdecoderに渡す実装を行うことで、unet構造のネットワークを構築している（実装ファイルのモデルプロットを見ることでネットワーク構造を把握することができる）

# %% [markdown]
# ### 【問題2】コードの書き換え
# エンコーダーにResNetが使用されていたコードをVGGに変更してください。

# %% [markdown]
# - [学習済のVGG19を利用して、unetを実装したファイル](https://github.com/satoshi30/diveintocode-ml/blob/master/Term2_DeepLearning/Sprint20/03_models_pretrained_and_more(vgg_unet).ipynb)

# %% [markdown]
# ### 【問題3】学習・推定
# ResNetとVGG双方のコードで学習・推定を行い、結果を比較してください。

# %% [markdown]
# - 2つの手法ともにepoch数を100にして学習・推定を行った
# - #### ResNet
#     - 学習後、ランダムに学習結果を表示（入力データ、正解データ、予測データ）
#     ![image](data:image/png;base64,...%0A)
#     - thresholdに応じたIoUを図示
#     ![image](data:image/png;base64,...%0A)

# %% [markdown]
# - #### VGG
#     - 学習後、ランダムに学習結果を表示（入力データ、正解データ、予測データ）
#     ![image](data:image/png;base64,...%0A)
#     - thresholdに応じたIoUを図示
#     ![image](data:image/png;base64,...%0A)

# %% [markdown]
# - 画像の出力を見ると、ランダムで抽出してはいるが、２つの手法とも凡そ正しく予測できていると思われる
# - 精度（IoU）は、resnetの方が高く出ている
#     - resnetの方が複数のunet構造（何か名称ある？）をとっており、モデルが複雑であるので、セマンティックセグメンテーションでの正確性が上がるのは当然といえば、当然か？
#     - しかし、学習時間はresnetの方が多くかかった（1epochあたり、ResNet:約60s、VGG:約40s）
